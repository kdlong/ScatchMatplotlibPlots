# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
plt.xkcd()
matplotlib.rcParams['figure.figsize'] = [5, 2]

# %%
plt.title("PDF uncertainty in $m_{W}$ (MeV)")
plt.barh(["$\\eta^{\\ell}/p_{T}^{\\ell}$ (NNPDF3.1)",  "$p_{T}^{\\ell}$ (NNPDF3.1)", "ATLAS",], [ 6.5, 13,9.4, ], height=.2, color='red')
plt.margins(0.5)
